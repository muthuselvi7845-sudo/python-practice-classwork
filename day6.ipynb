# %%
a=int(input("enter number:"))
b=int(input("enter number:"))
c=int(input("enter number:"))

if a>b:
    print("a  is greater")
elif b>c:
    print("b is greater")
else:
    print("c is greater")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 a=int(input("enter number:"))
#       2 b=int(input("enter number:"))
#       3 c=int(input("enter number:"))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
#home work
#infosys   python  1 experience location chennai
#wipro     python freser    location coimbatore
#tcs       java    freser  chennai
#coghizant java    1 experience banglore
