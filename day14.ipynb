# %%
for i in range(2,13,2):
    print(i)
# Out:
# 2
# 4
# 6
# 8
# 10
# 12

# %%
for i in range(11):
    pass

# %%
l={1,2,3,4,5}
for i in l:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
l=[1,2,3,4,5]
for i in l:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
l={2,6,7,6,2}
for i in l:
    print(i)
# Out:
# 2
# 6
# 7
