# %%
List=[1,1,"Hi",1.8,7.81,"True"]
List[0]="python"
print(List)
# Out:
# ['python', 1, 'Hi', 1.8, 7.81, 'True']

# %%
L=["hi","2","Hello",75]
L[1]=36
L.pop(2)
L.append("86")
print(L)
# Out:
# ['hi', 36, 75, '86']

# %%
L=[1,2,3,4,5,6,7,8]
L[2:4]="Hi"
print(L)
