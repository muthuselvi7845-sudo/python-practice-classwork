# %%
print("Hello world")
# Out:
# Hello world

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello!")
# Out:
# hello!

# %%
print("muthu selvi")
# Out:
# muthu selvi

# %%
print("hii")
# Out:
# hii
