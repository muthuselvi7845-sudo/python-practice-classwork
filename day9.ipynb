# %%
S1={"Hi","Hello",5,6,7,8}
S2={2,3,4,5}
S1.remove("Hello")
print(S1)
S1.update(S2)
print(S1)
S1.pop()
print(S1)
# Out:
# {5, 6, 7, 8, 'Hi'}
# {2, 3, 4, 5, 6, 7, 8, 'Hi'}
# {3, 4, 5, 6, 7, 8, 'Hi'}
